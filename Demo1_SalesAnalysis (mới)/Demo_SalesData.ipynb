# %% [markdown]
# <div align="center">
#
# <img src ='Pic\logo_CNTT.png' width='100px'>
#
# <div align="center">
#
# <h2> MÔN HỌC: KHOA HỌC DỮ LIỆU </h2>
#
# </div>
#
#
# ---
# <div align="center">
#     <h1> CÁC BƯỚC THỰC HIỆN MỘT DỰ ÁN PHÂN TÍCH DỮ LIỆU</h1>
# </div>
#
#
# <img src='Pic/process.png' width='300px'>
#
# ---
# *Copyright: Trần Hải Nam - Trần Trung Dũng - Nguyễn Văn Trọng -  TTDLDC.C06.BCA*

# %% [markdown]
# ## Bước 1: Xác định mục tiêu của dự án
# ---
# <img src='pic/chainstores.jpg' width=500px>
#
# Công ty bao gồm một chuỗi 10 cửa hàng kinh doanh đồ điện tử, được đặt tại 10 thành phố của 8 bang nước Mỹ.
#
# 1. Austin (TX - Texas)
# 2. Dallas (TX - Texas)
# 3. San Francisco (CA - California)
# 4. Los Angeles (CA - California)
# 5. New York City (NY - New York)
# 6. Portland (ME - Maine)
# 7. Portland (OR - Oregon)
# 8. Atlanta (GA - Georgia)
# 9. Seattle (WA - Washington)
# 10. Boston (MA - Massachusetts)

# %% [markdown]
# **Mục tiêu của dự án:**
# * Đánh giá hoạt động kinh doanh của chuỗi cửa hàng trong năm 2019
# * Thực hiện phân tích tìm ra các thông tin có ích (insights) từ dữ liệu để cải thiện, nâng cao hoạt động kinh doanh tại các cửa hàng.
# ---
# 1. **Câu hỏi 1:** *Cửa hàng ở thành phố nào hoạt động hiệu quả nhất?*
# 2. **Câu hỏi 2:** *Tháng nào trong năm có doanh số bán hàng cao nhất - thấp nhất?*
# 3. **Câu hỏi 3:** *Khách hàng mua sản phẩm thường tập trung vào khung giờ nào trong ngày?*
# 4. **Câu hỏi 4:** *Khách hàng thường mua các Sản phẩm nào cùng với nhau?*
# 5. **Câu hỏi 5:** *Sản phẩm nào bán được số lượng nhiều nhất? Tại sao?*

# %% [markdown]
# ## Bước 2: Thu thập và mô tả dữ liệu:
# ---
# Thu thập được tất cả dữ liệu liên quan đến bán hàng trong năm 2019:
#
# <img src='pic/data-colection.jpeg' width=500px height=200px>
#
# Dữ liệu bao gồm 12 file của chuỗi cửa hàng kinh doanh này; Mỗi file dữ liệu lưu lại toàn bộ các đơn hàng đã bán được theo từng tháng tương ứng của năm 2019.
# * Dữ liệu tháng 1: Sales_January_2019.csv
# * Dữ liệu tháng 2: Sales_February_2019.csv
# * Dữ liệu tháng 3: Sales_March_2019.csv
# * Dữ liệu tháng 4: Sales_April_2019.csv
# * Dữ liệu tháng 5: Sales_May_2019.csv
# * Dữ liệu tháng 6: Sales_June_2019.csv
# * Dữ liệu tháng 7: Sales_July_2019.csv
# * Dữ liệu tháng 8: Sales_August_2019.csv
# * Dữ liệu tháng 9: Sales_September_2019.csv
# * Dữ liệu tháng 10: Sales_October_2019.csv
# * Dữ liệu tháng 11: Sales_November_2019.csv
# * Dữ liệu tháng 12: Sales_December_2019.csv
#
# Mỗi file dữ liệu bao gồm 6 thông tin:
# 1. Order ID: Mã đơn hàng
# 2. Product: Tên sản phẩm đã bán theo từng đơn hàng
# 3. Quantity Ordered: Số lượng sản phẩm bán
# 4. Price Each: Giá của mỗi sản phẩm
# 5. Order Date: Thời gian bán hàng
# 6. Purchase Address: Địa chỉ mua hàng

# %%
### Đọc và tổng hợp các file dữ liệu bán hàng
---

# %%
#Hiển thị dữ liệu trong 1 file:
df1 = pd.read_csv('Data/01_Sales_January_2019.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
#Hiển thị 5 dòng dữ liệu đầu tiên
df1.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
#Hiển thị 5 dòng dữ liệu cuối cùng
df1.tail()
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 9718   150497            20in Monitor                1     109.99
# 9719   150498        27in FHD Monitor                1     149.99
# 9720   150499         ThinkPad Laptop                1     999.99
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9722   150501            Google Phone                1        600
#
#           Order Date                     Purchase Address
# 9718  01/26/19 19:09          95 8th St, Dallas, TX 75001
# 9719  01/10/19 22:58  403 7th St, San Francisco, CA 94016
# 9720  01/21/19 14:31      214 Main St, Portland, OR 97035
# 9721  01/15/19 14:21    810 2nd St, Los Angeles, CA 90001
# 9722  01/13/19 16:43       428 Cedar St, Boston, MA 02215

# %% [markdown]
# #### Tổng hợp dữ liệu bán hàng
# ---
# Đọc dữ liệu trong từng file riêng biệt, nối thành một tập dữ liệu chung để xử lý:

# %%
os.remove('Data/.DS_Store')

# %%
path ='./Data'

#Tạo một DataFrame rỗng
all_data_2019 = pd.DataFrame()

#Đọc dữ liệu trong từng file dữ liệu và tổng hợp thành một DataFrame chung
for file in os.listdir(path):
    path_file = path+'/'+file
    #print(path_file)
    current_data = pd.read_csv(path_file)
    print(file, '---',current_data.shape[0])
    
    all_data_2019 = all_data_2019.append(current_data)
# Out:
# 05_Sales_May_2019.csv --- 16635
# 03_Sales_March_2019.csv --- 15226
# 10_Sales_October_2019.csv --- 20379
# 11_Sales_November_2019.csv --- 17661
# 12_Sales_December_2019.csv --- 24955
# 04_Sales_April_2019.csv --- 18383
# 09_Sales_September_2019.csv --- 11686
# 01_Sales_January_2019.csv --- 9723
# 02_Sales_February_2019.csv --- 12036
# 08_Sales_August_2019.csv --- 12011
# 07_Sales_July_2019.csv --- 14371
# 06_Sales_June_2019.csv --- 13622

# %%
#Hiển thông tin biến all_data_2019
all_data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186688 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186223 non-null  object
#  1   Product           186223 non-null  object
#  2   Quantity Ordered  186223 non-null  object
#  3   Price Each        186223 non-null  object
#  4   Order Date        186223 non-null  object
#  5   Purchase Address  186223 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
#Hiển thị 5 dòng dữ liệu đầu tiên:
all_data_2019.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101

# %%
#Hiển thị 5 dòng dữ liệu cuối cùng:
all_data_2019.tail()
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 13617   222905  AAA Batteries (4-pack)                1       2.99
# 13618   222906        27in FHD Monitor                1     149.99
# 13619   222907    USB-C Charging Cable                1      11.95
# 13620   222908    USB-C Charging Cable                1      11.95
# 13621   222909  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                       Purchase Address
# 13617  06/07/19 19:02          795 Pine St, Boston, MA 02215
# 13618  06/01/19 19:29  495 North St, New York City, NY 10001
# 13619  06/22/19 18:57  319 Ridge St, San Francisco, CA 94016
# 13620  06/26/19 18:35   916 Main St, San Francisco, CA 94016
# 13621  06/25/19 14:33         209 11th St, Atlanta, GA 30301

# %%
#Lưu Dữ liệu ra file CSV:
all_data_2019.to_csv("all_Data_2019.csv", index=False)

# %% [markdown]
# # Bước 3. Chuẩn bị dữ liệu
# ---
# <img src='Pic/datapreparation.png'  width=500px>
#
# Dữ liệu thu thập được đều là dữ liệu thô, chứa rất nhiều nhiễu (noise), dữ liệu thiếu, dữ liệu sai định dạng, không nhất quán….Dữ liệu này không thể phân tích được ---> Cần phải được tiền xử lý và làm sạch.

# %% [markdown]
# ### 3.1 Xử lý các dòng rỗng không có giá trị trong tập dữ liệu
# ---
# Trong Data thu thập có rất nhiều dòng không có giá trị, chúng ta sẽ lọc và loại bỏ những dòng này khỏi Data

# %%
#Đọc file dữ liệu tổng hợp để chuẩn bị
all_data = pd.read_csv('all_Data_2019.csv')
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186688 entries, 0 to 186687
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186223 non-null  object
#  1   Product           186223 non-null  object
#  2   Quantity Ordered  186223 non-null  object
#  3   Price Each        186223 non-null  object
#  4   Order Date        186223 non-null  object
#  5   Purchase Address  186223 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
#Quan sát dữ liệu:
all_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101

# %%
#Kiểm tra số lượng bản ghi null trong Dữ liệu:
all_data.isnull().sum()
# Out:
# Order ID            465
# Product             465
# Quantity Ordered    465
# Price Each          465
# Order Date          465
# Purchase Address    465
# dtype: int64

# %%
# Liệt kê một số bản ghi NAN
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())
print('Tổng số dòng không có dữ liệu:', nan_df.shape[0])
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 58        NaN     NaN              NaN        NaN        NaN              NaN
# 111       NaN     NaN              NaN        NaN        NaN              NaN
# 522       NaN     NaN              NaN        NaN        NaN              NaN
# 839       NaN     NaN              NaN        NaN        NaN              NaN
# 1590      NaN     NaN              NaN        NaN        NaN              NaN
# Tổng số dòng không có dữ liệu: 465

# %%
#Xóa tất cả các dòng dữ liệu rỗng
all_data.dropna(how='all',inplace=True)

#Reset lại chỉ số cột
all_data.reset_index(drop=True,inplace=True)

all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186223 entries, 0 to 186222
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186223 non-null  object
#  1   Product           186223 non-null  object
#  2   Quantity Ordered  186223 non-null  object
#  3   Price Each        186223 non-null  object
#  4   Order Date        186223 non-null  object
#  5   Purchase Address  186223 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %% [markdown]
# ### 3.2) Xử lý các dòng tiêu đề trong Dữ liệu:
# ----
# Dữ liệu trong các file lưu trữ thông tin bán sản phẩm của mỗi tháng được tổng hợp từ nhiều sheet nên chứa các tiêu đề cột bị lặp lại:
#
# **Order ID -- Product -- Quantity Ordered -- Price Each -- Order Date -- Purchase Address**

# %%
all_data.iloc[958:975,:]
# Out:
#      Order ID                     Product  Quantity Ordered  Price Each  \
# 958    195005            Wired Headphones                 1       11.99
# 959    195006        USB-C Charging Cable                 1       11.95
# 960  Order ID                     Product  Quantity Ordered  Price Each
# 961    195007                      iPhone                 1         700
# 962    195008                      iPhone                 1         700
# 963    195009  Bose SoundSport Headphones                 1       99.99
# 964    195010        USB-C Charging Cable                 2       11.95
# 965    195011            Wired Headphones                 1       11.99
# 966    195012  Bose SoundSport Headphones                 1       99.99
# 967    195013        USB-C Charging Cable                 1       11.95
# 968    195014               Flatscreen TV                 1         300
# 969  Order ID                     Product  Quantity Ordered  Price Each
# 970    195015    Lightning Charging Cable                 1       14.95
# 971  Order ID                     Product  Quantity Ordered  Price Each
# 972    195016    Lightning Charging Cable                 1       14.95
# 973    195017      AAA Batteries (4-pack)                 2        2.99
# 974    195018      AAA Batteries (4-pack)                 1        2.99
#
#          Order Date                         Purchase Address
# 958  05/08/19 05:32        939 Walnut St, Portland, OR 97035
# 959  05/07/19 17:23   618 Spruce St, San Francisco, CA 94016
# 960      Order Date                         Purchase Address
# 961  05/14/19 08:45        757 Meadow St, Portland, OR 97035
# 962  05/09/19 10:29           305 Lake St, Seattle, WA 98101
# 963  05/05/19 07:54   688 Cherry St, San Francisco, CA 94016
# 964  05/05/19 22:29      543 River St, Los Angeles, CA 90001
# 965  05/13/19 13:43   440 Walnut St, New York City, NY 10001
# 966  05/15/19 16:53     365 Hill St, New York City, NY 10001
# 967  05/17/19 10:26   162 Wilson St, San Francisco, CA 94016
# 968  05/27/19 13:47  852 Johnson St, San Francisco, CA 94016
# 969      Order Date                         Purchase Address
# 970  05/06/19 10:28     219 Sunset St, Los Angeles, CA 90001
# 971      Order Date                         Purchase Address
# 972  05/01/19 22:29       282 West St, Los Angeles, CA 90001
# 973  05/14/19 07:16  804 Lincoln St, San Francisco, CA 94016
# 974  05/08/19 11:22          389 River St, Seattle, WA 98101

# %%
#Liệt kê các dòng tiêu đề trong Data:
all_data[all_data['Order ID']=='Order ID']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 960     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 969     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 971     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1314    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1351    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 183056  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 183396  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 183425  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 183658  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185906  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 960     Purchase Address
# 969     Purchase Address
# 971     Purchase Address
# 1314    Purchase Address
# 1351    Purchase Address
# ...                  ...
# 183056  Purchase Address
# 183396  Purchase Address
# 183425  Purchase Address
# 183658  Purchase Address
# 185906  Purchase Address
#
# [307 rows x 6 columns]

# %%
#Lọc và loại bỏ tất cả các dòng tiêu đề trong Data
all_data = all_data[all_data['Order ID']!='Order ID']

#Reset lại index của DataFrame:
all_data.reset_index(drop=True,inplace=True)

all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185916 entries, 0 to 185915
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185916 non-null  object
#  1   Product           185916 non-null  object
#  2   Quantity Ordered  185916 non-null  object
#  3   Price Each        185916 non-null  object
#  4   Order Date        185916 non-null  object
#  5   Purchase Address  185916 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
all_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101

# %% [markdown]
# ## 3.3) Chuyển đổi kiểu dữ liệu các cột số
# ---
# * Dữ liệu của 2 cột 'Quantity Ordered', Price Each đang ở dạng object --> Chuyển sang kiểu dữ liệu số
# * Dữ liệu của cột Order Date đang ở dạng object --> Chuyển sang dạng date time

# %%
#Chuyển đổi kiểu dữ liệu sang dạng số:
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

#Chuyển đổi kiểu dữ liệu sang dạng time:
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185916 entries, 0 to 185915
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185916 non-null  object
#  1   Product           185916 non-null  object
#  2   Quantity Ordered  185916 non-null  int64
#  3   Price Each        185916 non-null  float64
#  4   Order Date        185916 non-null  datetime64[ns]
#  5   Purchase Address  185916 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 8.5+ MB

# %%
all_data.head()

# %%
#Quan sát đặc trưng thống kê của trường Số lượng - Giá
all_data.describe()
# Out:
#        Quantity Ordered     Price Each
# count     185916.000000  185916.000000
# mean           1.124368     184.387720
# std            0.442749     332.722426
# min            1.000000       2.990000
# 25%            1.000000      11.950000
# 50%            1.000000      14.950000
# 75%            1.000000     150.000000
# max            9.000000    1700.000000

# %% [markdown]
# ### 3.4) Thêm các cột dữ liệu mới phục vụ phân tích
# ---

# %% [markdown]
# #### 1. Cột Month, Hour: Month và Hour được tách ra từ cột Order Date lấy tháng, giờ mua hàng

# %%
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#            Order Date                         Purchase Address
# 0 2019-05-16 17:14:00      669 2nd St, New York City, NY 10001
# 1 2019-05-19 14:43:00          844 Walnut St, Dallas, TX 75001
# 2 2019-05-24 11:36:00  164 Madison St, New York City, NY 10001
# 3 2019-05-02 20:40:00          622 Meadow St, Dallas, TX 75001
# 4 2019-05-11 22:55:00          17 Church St, Seattle, WA 98101

# %%
#
all_data['Month'] = all_data['Order Date'].dt.month
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#            Order Date                         Purchase Address  Month  Hour
# 0 2019-05-16 17:14:00      669 2nd St, New York City, NY 10001      5    17
# 1 2019-05-19 14:43:00          844 Walnut St, Dallas, TX 75001      5    14
# 2 2019-05-24 11:36:00  164 Madison St, New York City, NY 10001      5    11
# 3 2019-05-02 20:40:00          622 Meadow St, Dallas, TX 75001      5    20
# 4 2019-05-11 22:55:00          17 Church St, Seattle, WA 98101      5    22

# %%
all_data.tail()

# %% [markdown]
# #### 2.Cột City: Tách tên thành phố trong địa chỉ mua hàng vào một cột mới

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#            Order Date                         Purchase Address  Month  Hour  \
# 0 2019-05-16 17:14:00      669 2nd St, New York City, NY 10001      5    17
# 1 2019-05-19 14:43:00          844 Walnut St, Dallas, TX 75001      5    14
# 2 2019-05-24 11:36:00  164 Madison St, New York City, NY 10001      5    11
# 3 2019-05-02 20:40:00          622 Meadow St, Dallas, TX 75001      5    20
# 4 2019-05-11 22:55:00          17 Church St, Seattle, WA 98101      5    22
#
#                   City
# 0  New York City  (NY)
# 1         Dallas  (TX)
# 2  New York City  (NY)
# 3         Dallas  (TX)
# 4        Seattle  (WA)

# %% [markdown]
# #### 3. cột Sales: Được tính bằng số lượng sản phẩm (Quantity Ordered) * Giá bán mỗi sản phẩm (Price Each)

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#            Order Date                         Purchase Address  Month  Hour  \
# 0 2019-05-16 17:14:00      669 2nd St, New York City, NY 10001      5    17
# 1 2019-05-19 14:43:00          844 Walnut St, Dallas, TX 75001      5    14
# 2 2019-05-24 11:36:00  164 Madison St, New York City, NY 10001      5    11
# 3 2019-05-02 20:40:00          622 Meadow St, Dallas, TX 75001      5    20
# 4 2019-05-11 22:55:00          17 Church St, Seattle, WA 98101      5    22
#
#                   City   Sales
# 0  New York City  (NY)   11.99
# 1         Dallas  (TX)    3.84
# 2  New York City  (NY)  149.99
# 3         Dallas  (TX)   11.99
# 4        Seattle  (WA)    5.98

# %% [markdown]
# ## 3.5) Lưu trữ dữ liệu sau khi làm sạch:
# ---

# %%
#Lưu dữ liệu sau xử lý ra file .CSV
all_data.to_csv('Data_OK.csv',index=None)

# %% [markdown]
# <img src='Pic/80.jpg' width='200px' align='left'>
# <h4 color='red'>
# LƯU Ý:
# Thu thập và chuẩn bị dữ liệu là bước quan trọng, chiếm nhiều thời gian và nguồn lực nhất trong bất kỳ một dự án khoa học dữ liệu nào (80%)
# </h4>

# %% [markdown]
# ## Bước 4. Phân tích, Khám phá tập dữ liệu
# ---
# <img src='Pic/analytics.jpg' width='400px'>

# %% [markdown]
# ### Câu hỏi 1: Cửa hàng ở thành phố nào (Khách hàng ở khu vực nào) bán được hàng nhiều nhất?
# ---
# Chuỗi bán hàng điện tử bao gồm 10 cửa hàng, đặt tại 10 thành phố của 8 bang ở Mỹ
# 1. Austin (TX - Texas)
# 2. Dallas (TX - Texas)
# 3. San Francisco (CA - California)
# 4. Los Angeles (CA - California)
# 5. New York City (NY - New York)
# 6. Portland (ME - Maine)
# 7. Portland (OR - Oregon)
# 8. Atlanta (GA - Georgia)
# 9. Seattle (WA - Washington)
# 10. Boston (MA - Massachusetts)

# %%
all_data.head()

# %%
#Group theo city, thực hiện tính tổng cột doanh số bán hàng
sale_city = all_data[['City','Sales']].groupby(['City']).sum()

#Sắp xếp dữ liệu theo doanh số bán hàng tăng dần
sale_city.sort_values('Sales',inplace=True)
sale_city
# Out:
#                           Sales
# City
# Portland  (ME)        449758.27
# Austin  (TX)         1819081.77
# Portland  (OR)       1870579.35
# Seattle  (WA)        2747605.49
# Dallas  (TX)         2766260.45
# Atlanta  (GA)        2795498.58
# Boston  (MA)         3660315.12
# New York City  (NY)  4662976.81
# Los Angeles  (CA)    5451570.81
# San Francisco  (CA)  8259719.03

# %%
#TRỰC QUAN HÓA DỮ LIỆU TRÊN BIỂU ĐỒ
#Tách dữ liệu để hiển thị
city_names = sale_city.index
city_sales = sale_city.values.ravel()

plt.figure(figsize=(10,4))
plt.bar(city_names,city_sales,color='brown')
plt.ylabel('Doanh số bán hàng (triệu USD)')
plt.xlabel('Thành phố')
plt.title('THỐNG KÊ DOANH SỐ BÁN HÀNG THEO TỪNG THÀNH PHỐ')
plt.xticks(city_names, rotation=75, size=12)
plt.grid(True)
plt.show()

# %% [markdown]
# <img src='Pic/insight.png' width='200px' align='left'>
#
#
#  **NHẬN XÉT 1:**
# ---
# * Thành phố San Francisco bang California có doanh số bán hàng tốt nhất khoảng 8.3 triệu USD, sau đó đến Los Angeles (CA) với doanh số khoảng 5.5 triệu USD --> Các cửa hàng ở CA hoạt động rất hiệu quả.
# * Thành phố có doanh số bán hàng thấp nhất là Portland (Maine) khoảng 0.5 triệu USD, sau đó là Austin (TX) và Portland (OR)

# %% [markdown]
# ### Câu hỏi 2: Tháng nào trong năm có doanh số bán hàng cao nhất - thấp nhất?

# %%
#Group theo tháng, thực hiện tính tổng cột doanh số bán hàng
sale_months = all_data[['Month','Sales']].groupby(['Month']).sum()
sale_months
# Out:
#             Sales
# Month
# 1      1813586.44
# 2      2202022.42
# 3      2807100.38
# 4      3390670.24
# 5      3152606.75
# 6      2577802.26
# 7      2647775.76
# 8      2244467.88
# 9      2097560.13
# 10     3736726.88
# 11     3199603.20
# 12     4613443.34

# %%
import matplotlib.pyplot as plt

months = np.arange(1,13) #Dữ liệu tháng hiển thị trục X
sales = sale_months['Sales'].values #Dữ liệu Sales hiển thị trục Y

plt.figure(figsize=(10,5))
plt.bar(months,sales)
plt.xticks(months)
plt.ticklabel_format(useOffset=False,style='plain')
plt.grid(True)
plt.ylabel('Doanh số ($)')
plt.xlabel('Tháng')
plt.title('THỐNG KÊ DOANH SỐ BÁN HÀNG THEO TỪNG THÁNG')
plt.show()

# %% [markdown]
# <img src='Pic/insight.png' width='200px' align='left'>
#
#
#  **NHẬN XÉT 2:**
# ---
# * Tháng 12 có doanh số bán hàng cao nhất với khoảng 4.7 triệu USD. Sau đoa là tháng 10 khoảng 3.7 triệu USD
# * Tháng có doanh số bán hàng thấp nhất là tháng 1 khoảng 1.8 triệu USD, tiếp sau là tháng 9 với khoảng 2.1 triệu USD

# %% [markdown]
# ### Câu hỏi 3: Khách hàng mua sản phẩm thường tập trung vào khung giờ nào trong ngày?
# ---

# %%
#Thống kê số lượng sản phẩm bán theo từng giờ (tổng số tất cả các sản phẩm)
product_hours = all_data[['Hour','Quantity Ordered']].groupby(['Hour']).sum()
product_hours
# Out:
#       Quantity Ordered
# Hour
# 0                 4412
# 1                 2610
# 2                 1394
# 3                  922
# 4                  933
# 5                 1491
# 6                 2810
# 7                 4556
# 8                 7002
# 9                 9816
# 10               12308
# 11               14005
# 12               14202
# 13               13685
# 14               12362
# 15               11391
# 16               11662
# 17               12229
# 18               13802
# 19               14470
# 20               13768
# 21               12244
# 22                9899
# 23                7065

# %%
hours = np.arange(0,24)
products = product_hours.values

plt.figure(figsize=(15,4))
plt.plot(hours,products, 'r--o')
plt.title('THỐNG KÊ SỐ LƯỢNG SẢN PHẨM BÁN ĐƯỢC THEO TỪNG GIỜ')
plt.xticks(hours)
plt.ylabel('Số đơn hàng')
plt.xlabel('Giờ trong ngày')

plt.grid()
plt.show()

# %% [markdown]
# <img src='Pic/insight.png' width='200px' align='left'>
#
#
#  **NHẬN XÉT 3:**
# ---
# * Khoảng thời gian mua hàng nhiều nhất 10 am --> 21 pm; cao điểm nhất là lúc 12 am và 19 pm

# %% [markdown]
# ### Câu hỏi 4: Trong các hóa đơn của Khách hàng, Sản phẩm nào thường được mua cùng với nhau?

# %%
#Lọc danh sách lấy các hóa đơn mua nhiều sản phẩm
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 15       194110              Google Phone                 1      600.00
# 16       194110          Wired Headphones                 1       11.99
# 76       194170              Google Phone                 1      600.00
# 77       194170      USB-C Charging Cable                 2       11.95
# 81       194174                    iPhone                 1      700.00
# ...         ...                       ...               ...         ...
# 185886   222882     AA Batteries (4-pack)                 1        3.84
# 185888   222884              Google Phone                 1      600.00
# 185889   222884      USB-C Charging Cable                 1       11.95
# 185908   222903                    iPhone                 1      700.00
# 185909   222903  Lightning Charging Cable                 1       14.95
#
#                 Order Date                         Purchase Address  Month  \
# 15     2019-05-31 18:07:00       498 14th St, Los Angeles, CA 90001      5
# 16     2019-05-31 18:07:00       498 14th St, Los Angeles, CA 90001      5
# 76     2019-05-30 12:30:00    711 Maple St, San Francisco, CA 94016      5
# 77     2019-05-30 12:30:00    711 Maple St, San Francisco, CA 94016      5
# 81     2019-05-04 23:08:00           37 North St, Seattle, WA 98101      5
# ...                    ...                                      ...    ...
# 185886 2019-06-18 11:37:00     990 Walnut St, Los Angeles, CA 90001      6
# 185888 2019-06-04 12:06:00     819 Pine St, New York City, NY 10001      6
# 185889 2019-06-04 12:06:00     819 Pine St, New York City, NY 10001      6
# 185908 2019-06-07 22:21:00  685 Hickory St, New York City, NY 10001      6
# 185909 2019-06-07 22:21:00  685 Hickory St, New York City, NY 10001      6
#
#         Hour                 City   Sales
# 15        18    Los Angeles  (CA)  600.00
# 16        18    Los Angeles  (CA)   11.99
# 76        12  San Francisco  (CA)  600.00
# 77        12  San Francisco  (CA)   23.90
# 81        23        Seattle  (WA)  700.00
# ...      ...                  ...     ...
# 185886    11    Los Angeles  (CA)    3.84
# 185888    12  New York City  (NY)  600.00
# 185889    12  New York City  (NY)   11.95
# 185908    22  New York City  (NY)  700.00
# 185909    22  New York City  (NY)   14.95
#
# [14643 rows x 10 columns]

# %%
#Ghép các sản phẩm lại với nhau theo từng mã Order ID, để xem sản phẩm nào hay mua cùng với nhau
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df[['Order ID','Product','Grouped']]
# Out:
#        Order ID                   Product  \
# 15       194110              Google Phone
# 16       194110          Wired Headphones
# 76       194170              Google Phone
# 77       194170      USB-C Charging Cable
# 81       194174                    iPhone
# ...         ...                       ...
# 185886   222882     AA Batteries (4-pack)
# 185888   222884              Google Phone
# 185889   222884      USB-C Charging Cable
# 185908   222903                    iPhone
# 185909   222903  Lightning Charging Cable
#
#                                                  Grouped
# 15                         Google Phone,Wired Headphones
# 16                         Google Phone,Wired Headphones
# 76                     Google Phone,USB-C Charging Cable
# 77                     Google Phone,USB-C Charging Cable
# 81      iPhone,Lightning Charging Cable,Wired Headphones
# ...                                                  ...
# 185886    Apple Airpods Headphones,AA Batteries (4-pack)
# 185888                 Google Phone,USB-C Charging Cable
# 185889                 Google Phone,USB-C Charging Cable
# 185908                   iPhone,Lightning Charging Cable
# 185909                   iPhone,Lightning Charging Cable
#
# [14643 rows x 3 columns]

# %%
#Lấy cột Order ID, Grouped, xóa các hóa đơn lặp lại
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
df2
# Out:
#        Order ID                                           Grouped
# 15       194110                     Google Phone,Wired Headphones
# 76       194170                 Google Phone,USB-C Charging Cable
# 81       194174  iPhone,Lightning Charging Cable,Wired Headphones
# 88       194179              Flatscreen TV,AAA Batteries (4-pack)
# 102      194192       Wired Headphones,Bose SoundSport Headphones
# ...         ...                                               ...
# 185864   222863       27in FHD Monitor,Bose SoundSport Headphones
# 185870   222868                   iPhone,Apple Airpods Headphones
# 185885   222882    Apple Airpods Headphones,AA Batteries (4-pack)
# 185888   222884                 Google Phone,USB-C Charging Cable
# 185908   222903                   iPhone,Lightning Charging Cable
#
# [7133 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(15):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 952
# ('Google Phone', 'USB-C Charging Cable') 925
# ('iPhone', 'Wired Headphones') 409
# ('Google Phone', 'Wired Headphones') 381
# ('iPhone', 'Apple Airpods Headphones') 336
# ('Vareebadd Phone', 'USB-C Charging Cable') 334
# ('Google Phone', 'Bose SoundSport Headphones') 209
# ('USB-C Charging Cable', 'Wired Headphones') 152
# ('Vareebadd Phone', 'Wired Headphones') 131
# ('Lightning Charging Cable', 'Wired Headphones') 90
# ('Lightning Charging Cable', 'Apple Airpods Headphones') 79
# ('Vareebadd Phone', 'Bose SoundSport Headphones') 75
# ('USB-C Charging Cable', 'Google Phone') 74
# ('USB-C Charging Cable', 'Bose SoundSport Headphones') 73
# ('Apple Airpods Headphones', 'Wired Headphones') 65

# %% [markdown]
# <img src='Pic/insight.png' width='200px' align='left'>
#
#
#  **NHẬN XÉT 4:**
# ---
#
# Thống kê trong toàn bộ các hóa đơn bán hàng, ta thấy những cặp sản phẩm thường được mua cùng nhau bao gồm
# * Phổ biến nhất là người dùng mua iPhone sẽ mua theo -> Lightning Charging Cable, -> Wire Headphone --> Apple Airpods Headphones.
# * Người dùng mua Google Phone thường sẽ mua theo --> USB-C Charging Cable --> Wired Headphones --> Bose SoundSport Headphones.
# * Người dùng mua Vareebadd Phone thường sẽ mua theo --> USB-C Charging Cable --> Wired Headphones

# %% [markdown]
# ### Câu hỏi 5: Sản phẩm nào của chuỗi cửa hàng bán chạy nhất? Tại sao nó lại bán được nhiều?
# ---
# Chuỗi cửa hàng điện tử này bán 19 mặt hàng bao gồm:
# 1. '20in Monitor',
# 2. '27in 4K Gaming Monitor',
# 3. '27in FHD Monitor',
# 4. '34in Ultrawide Monitor',
# 5. 'AA Batteries (4-pack)',
# 6. 'AAA Batteries (4-pack)',
# 7. 'Apple Airpods Headphones',
# 8. 'Bose SoundSport Headphones',
# 9. 'Flatscreen TV',
# 10. 'Google Phone',
# 11. 'LG Dryer',
# 12. 'LG Washing Machine',
# 13. 'Lightning Charging Cable',
# 14. 'Macbook Pro Laptop',
# 15. 'ThinkPad Laptop',
# 16. 'USB-C Charging Cable',
# 17. 'Vareebadd Phone',
# 18. 'Wired Headphones',
# 19. 'iPhone'

# %%
#Thống kê số lượng sản phẩm bán được theo mặt hàng
products_count = all_data[['Product','Quantity Ordered']].groupby('Product').sum()
products_count

# %%
#Trực quan hóa dữ liệu
#Tách dữ liệu để hiển thị
product_names = products_count.index
product_num = products_count.values.ravel()


plt.figure(figsize=(15,5))
plt.bar(product_names, product_num)
plt.ylabel('Số sản phẩm bán được')
plt.xticks(product_names, rotation=90, size=12)
plt.title('THỐNG KÊ SỐ LƯỢNG SẢN PHẨM BÁN ĐƯỢC TRONG NĂM 2019')
plt.grid(True)
plt.show()

# %%
#Trực quan hóa thêm giá tương ứng của mỗi sản phẩm vào đồ thị
prices = all_data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots(figsize=(15,5))

ax2 = ax1.twinx()
ax1.bar(product_names, product_num, color='g')
ax2.plot(product_names, prices, 'b-o')

ax1.set_title('BIỂU ĐỒ THỂ HIỆN SỐ LƯỢNG SẢN PHẨM BÁN ĐƯỢC VÀ GIÁ CỦA MẶT HÀNG ĐÓ')
ax1.set_ylabel('Số sản phẩm bán được', color='g')
ax2.set_ylabel('Giá sản phẩm ($)', color='b')
ax1.set_xticklabels(product_names, rotation='vertical', size=8)
ax1.grid(True)
fig.show()

# %% [markdown]
# <img src='Pic/insight.png' width='200px' align='left'>
#
#
#  **NHẬN XÉT 5:**
# ---
#
# * Trong số các sản phẩm được bán, các mặt hàng bán được số lượng nhiều nhất bao gồm: AA Batteries (4-pack), AA Batteries (4-pack); USB-C Charging Cable; Lightning Charging Cable; Wired Headphones; --> Lý do: Giá bán các mặt hàng này trên  mỗi sản phẩm thấp.
# * Các sản phẩm bán được số lượng ít nhất bao gồm: LG Dryer; LG Washing Machine; Vareebadd Phone; 20in Monitor;ThinkPad Laptop --> Một trong số các lý do: Giá bán cao

# %% [markdown]
# <img src='Pic/action.jpg' width='700px'>
